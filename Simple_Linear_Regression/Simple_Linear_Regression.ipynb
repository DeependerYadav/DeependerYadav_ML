# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df  = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
x = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 2)

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
lr.fit(X_train, y_train)
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color = 'red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_
b
# Out:
# np.float64(-0.8961119222429144)

# %%
print(f"y = {m}x + {b}")
# Out:
# y = [0.55795197]x + -0.8961119222429144

# %% [markdown]
# # Another DataSet

# %%
dfs = pd.read_csv('Salary_dataset.csv')

# %%
dfs.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
plt.scatter(dfs['YearsExperience'],dfs['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary( in thousand)')
# Out:
# Text(0, 0.5, 'Salary( in thousand)')

# %%
X = dfs.iloc[:, 1:2]
Y = dfs.iloc[:, -1]

# %%
X
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, Y_tarin, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 2)

# %%
x_test
# Out:
#     YearsExperience
# 1               1.4
# 0               1.2
# 14              4.6
# 9               3.8
# 21              7.2
# 19              6.1

# %%
from sklearn.linear_model import LinearRegression
lrs = LinearRegression()

# %%
lrs.fit(x_train, Y_tarin)
# Out:
# LinearRegression()

# %%
Y_test
# Out:
# 1     46206.0
# 0     39344.0
# 14    61112.0
# 9     57190.0
# 21    98274.0
# 19    93941.0
# Name: Salary, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(dfs['YearsExperience'],dfs['Salary'])
plt.plot(x_train, lrs.predict(x_train), color = 'red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary( in thousand)')
# Out:
# Text(0, 0.5, 'Salary( in thousand)')

# %%
m = lrs.coef_
m
# Out:
# array([9569.58688543])

# %%
b = lrs.intercept_
b
# Out:
# np.float64(23437.21046340505)

# %%
# y = mx + b

m * 5 + b
# Out:
# array([71285.14489057])

# %%
# y = mx + b

m * 9.5 + b
# Out:
# array([114348.28587502])
